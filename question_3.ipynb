# %%
# !pip install nbformat
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\Stuti\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import nbformat

with open("C:/Users/Stuti/Downloads/vscode/.vscode/Practise/micorza/question_2/question_2.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

if "widgets" in nb.metadata:
    del nb.metadata["widgets"]

with open("your_notebook_cleaned.ipynb", "w", encoding="utf-8") as f:
    nbformat.write(nb, f)

# %% [markdown]
# # Zero-Shot Classification with LLMs (Prompt Engineering Focus)

# %% [markdown]
# ## 1. Setup

# %%
# !pip install transformers datasets scikit-learn seaborn matplotlib accelerate -q

# %% [markdown]
# ## 1. Importing libraries

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from datasets import load_dataset

# %% [markdown]
# ## 2. Dataset Preparation

# %%
# Using Emotion Dataset with unseen emotion labels
emotion_dataset = load_dataset("emotion")
df = emotion_dataset['train'].to_pandas().sample(50, random_state=42)
texts = df['text'].tolist()
labels = df['label'].map({0: "sadness", 1: "joy", 2: "love", 3: "anger", 4: "fear", 5: "surprise"}).tolist()
unique_labels = list(set(labels))

# %% [markdown]
# ## 3. Prompt Templates

# %% [markdown]
# ## 4. Prediction Function (OpenAI API)

# %%
# def classify_with_prompt(prompt_template, text, labels):
#     prompt = prompt_template.format(text=text, labels=", ".join(labels))
#     response = client.chat.complete(
#         model="mistral-tiny",
#         messages=[{"role": "user", "content": prompt}],
#         temperature=0.0,
#         max_tokens=20
#     )
#     return response.choices[0].message['content'].strip().lower()

def classify_with_prompt(prompt_template, text, labels):
    prompt = prompt_template.format(text=text, labels=", ".join(labels))
    response = client.chat.complete(
        model="mistral-tiny",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.0,
        max_tokens=20
    )
    return response.choices[0].message.content.strip().lower()

# %%
## 5. Run for All Prompts
results = []
for name, template in TEMPLATES.items():
    preds = []
    for text in texts:
        pred = classify_with_prompt(template, text, unique_labels)
        preds.append(pred)
    results.append((name, preds))
# Out:
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# <ipython-input-38-ebc0a17b4413> in <cell line: 0>()
#       4     preds = []
#       5     for text in texts:
# ----> 6         pred = classify_with_prompt(template, text, unique_labels)
#       7         preds.append(pred)
#       8     results.append((name, preds))
#
# <ipython-input-37-9a2061f780eb> in classify_with_prompt(prompt_template, text, labels)
#      11 def classify_with_prompt(prompt_template, text, labels):
#      12     prompt = prompt_template.format(text=text, labels=", ".join(labels))
# ---> 13     response = client.chat.complete(
#      14         model="mistral-tiny",
#      15         messages=[{"role": "user", "content": prompt}],
#
# ...

# %%
# %pip openai migrate
# Out:
# ERROR: unknown command "openai"
